# %% [markdown]
# ## Part 1
#
# ### 1. Write a function (program) to connect to sources and download data

# %% [markdown]
# ### Yahoo/Google Finance API / URL not working. How to fix it?
#
# Here is the stack overflow page.
#
# https://stackoverflow.com/questions/44112403/yahoo-finance-api-url-not-working-python-fix-for-pandas-datareader
#
# Quora page:
#
# https://www.quora.com/Using-Python-whats-the-best-way-to-get-stock-data

# %% [markdown]
# ### Yahoo finance

# %%
import matplotlib.pyplot as plt
import fix_yahoo_finance as yf  
data = yf.download('AAPL','2016-01-01','2018-01-01')
data.Close.plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
from pandas_datareader import data as pdr

import fix_yahoo_finance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")

# download Panel
data = pdr.get_data_yahoo(["SPY", "VIX","AMZN"], start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  3 of 3 downloaded

# %%
data.loc[:,:,'AMZN']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  757.919983  758.760010  747.700012  753.669983  753.669983
# 2017-01-04  758.390015  759.679993  754.200012  757.179993  757.179993
# 2017-01-05  761.549988  782.400024  760.260010  780.450012  780.450012
# 2017-01-06  782.359985  799.440002  778.479980  795.989990  795.989990
# 2017-01-09  798.000000  801.770020  791.770020  796.919983  796.919983
# 2017-01-10  796.599976  798.000000  789.539978  795.900024  795.900024
# 2017-01-11  793.659973  799.500000  789.510010  799.020020  799.020020
# 2017-01-12  800.309998  814.130005  799.500000  813.640015  813.640015
# 2017-01-13  814.320007  821.650024  811.400024  817.140015  817.140015
# 2017-01-17  815.700012  816.000000  803.440002  809.719971  809.719971
# 2017-01-18  809.500000  811.729980  804.270020  807.479980  807.479980
# 2017-01-19  810.000000  813.510010  807.320007  809.039978  809.039978
# 2017-01-20  815.280029  816.020020  806.260010  808.330017  808.330017
# 2017-01-23  806.799988  818.500000  805.080017  817.880005  817.880005
# 2017-01-24  822.000000  823.989990  814.500000  822.440002  822.440002
# 2017-01-25  825.789978  837.419983  825.289978  836.520020  836.520020
# 2017-01-26  835.530029  843.840027  833.000000  839.150024  839.150024
# 2017-01-27  839.000000  839.700012  829.440002  835.770020  835.770020
# 2017-01-30  833.000000  833.500000  816.380005  830.380005  830.380005
# 2017-01-31  823.750000  826.989990  819.559998  823.479980  823.479980
# 2017-02-01  829.210022  833.780029  824.940002  832.349976  832.349976
# 2017-02-02  836.590027  842.489990  828.260010  839.950012  839.950012
# 2017-02-03  806.719971  818.299988  804.000000  810.200012  810.200012
# 2017-02-06  809.799988  810.719971  803.000000  807.640015  807.640015
# 2017-02-07  809.309998  816.159973  807.500000  812.500000  812.500000
# 2017-02-08  812.690002  821.479980  812.500000  819.710022  819.710022
# 2017-02-09  821.599976  825.000000  819.710022  821.359985  821.359985
# 2017-02-10  823.820007  828.000000  822.849976  827.460022  827.460022
# 2017-02-13  831.619995  843.000000  828.549988  836.530029  836.530029
# 2017-02-14  837.000000  838.309998  831.450012  836.390015  836.390015
# ...                ...         ...         ...         ...         ...
# 2017-03-17  853.489990  853.830017  850.640015  852.309998  852.309998
# 2017-03-20  851.510010  857.799988  851.010010  856.969971  856.969971
# 2017-03-21  858.840027  862.799988  841.309998  843.200012  843.200012
# 2017-03-22  840.429993  849.369995  839.049988  848.059998  848.059998
# 2017-03-23  848.200012  850.890015  844.799988  847.380005  847.380005
# 2017-03-24  851.679993  851.799988  843.530029  845.609985  845.609985
# 2017-03-27  838.070007  850.299988  833.500000  846.820007  846.820007
# 2017-03-28  851.750000  858.460022  850.099976  856.000000  856.000000
# 2017-03-29  859.049988  876.440002  859.020020  874.320007  874.320007
# 2017-03-30  874.950012  877.059998  871.659973  876.340027  876.340027
# 2017-03-31  877.000000  890.349976  876.650024  886.539978  886.539978
# 2017-04-03  888.000000  893.489990  885.419983  891.510010  891.510010
# 2017-04-04  891.500000  908.539978  890.280029  906.830017  906.830017
# 2017-04-05  910.820007  923.719971  905.619995  909.280029  909.280029
# 2017-04-06  913.799988  917.190002  894.489990  898.280029  898.280029
# 2017-04-07  899.650024  900.090027  889.309998  894.880005  894.880005
# 2017-04-10  899.630005  908.510010  899.000000  907.039978  907.039978
# 2017-04-11  907.039978  911.239990  897.500000  902.359985  902.359985
# 2017-04-12  903.090027  904.090027  895.250000  896.229980  896.229980
# 2017-04-13  891.450012  894.969971  884.489990  884.669983  884.669983
# 2017-04-17  887.500000  902.380005  887.500000  901.989990  901.989990
# 2017-04-18  900.989990  909.609985  900.780029  903.780029  903.780029
# 2017-04-19  907.840027  910.500000  897.369995  899.200012  899.200012
# 2017-04-20  899.700012  905.320007  896.289978  902.059998  902.059998
# 2017-04-21  902.669983  903.650024  896.770020  898.530029  898.530029
# 2017-04-24  908.679993  909.989990  903.820007  907.409973  907.409973
# 2017-04-25  907.039978  909.479980  903.000000  907.619995  907.619995
# 2017-04-26  910.299988  915.750000  907.559998  909.289978  909.289978
# 2017-04-27  914.390015  921.859985  912.109985  918.380005  918.380005
# 2017-04-28  948.830017  949.590027  924.330017  924.989990  924.989990
#
#                 Volume
# Date
# 2017-01-03   3521100.0
# 2017-01-04   2510500.0
# 2017-01-05   5830100.0
# 2017-01-06   5986200.0
# 2017-01-09   3440100.0
# 2017-01-10   2558400.0
# 2017-01-11   2992800.0
# 2017-01-12   4873900.0
# 2017-01-13   3791900.0
# 2017-01-17   3659400.0
# 2017-01-18   2354200.0
# 2017-01-19   2540800.0
# 2017-01-20   3376200.0
# 2017-01-23   2797500.0
# 2017-01-24   2971700.0
# 2017-01-25   3922600.0
# 2017-01-26   3586300.0
# 2017-01-27   2998700.0
# 2017-01-30   3747300.0
# 2017-01-31   3137200.0
# 2017-02-01   3850200.0
# 2017-02-02   7350500.0
# 2017-02-03  10868800.0
# 2017-02-06   3897300.0
# 2017-02-07   3466100.0
# 2017-02-08   2858000.0
# 2017-02-09   2484900.0
# 2017-02-10   2429600.0
# 2017-02-13   4172600.0
# 2017-02-14   2787900.0
# ...                ...
# 2017-03-17   3384400.0
# 2017-03-20   2282700.0
# 2017-03-21   4382900.0
# 2017-03-22   2658700.0
# 2017-03-23   1953000.0
# 2017-03-24   2138300.0
# 2017-03-27   2755800.0
# 2017-03-28   3041600.0
# 2017-03-29   4485800.0
# 2017-03-30   2762700.0
# 2017-03-31   3957600.0
# 2017-04-03   3422300.0
# 2017-04-04   4984700.0
# 2017-04-05   7508400.0
# 2017-04-06   6344100.0
# 2017-04-07   3710900.0
# 2017-04-10   3184300.0
# 2017-04-11   3012700.0
# 2017-04-12   2456100.0
# 2017-04-13   3174600.0
# 2017-04-17   2854700.0
# 2017-04-18   2999200.0
# 2017-04-19   2870200.0
# 2017-04-20   2814400.0
# 2017-04-21   2420500.0
# 2017-04-24   3122900.0
# 2017-04-25   3380600.0
# 2017-04-26   2608900.0
# 2017-04-27   5305500.0
# 2017-04-28   7335800.0
#
# [81 rows x 6 columns]

# %% [markdown]
# ### Quandl api

# %%
import quandl
quandl.api_config.api_key="UPvqTbKx9vob_1xzMsei"
data = quandl.get("WIKI/AAPL", start_date="2016-01-01", end_date="2018-01-01")
data.Close.plot()
plt.show()

# %%
data.head()
# Out:
#               Open     High     Low   Close      Volume  Ex-Dividend  \
# Date
# 2016-01-04  102.61  105.368  102.00  105.35  67649387.0          0.0
# 2016-01-05  105.75  105.850  102.41  102.71  55790992.0          0.0
# 2016-01-06  100.56  102.370   99.87  100.70  68457388.0          0.0
# 2016-01-07   98.68  100.130   96.43   96.45  81094428.0          0.0
# 2016-01-08   98.55   99.110   96.76   96.96  70798016.0          0.0
#
#             Split Ratio   Adj. Open   Adj. High   Adj. Low  Adj. Close  \
# Date
# 2016-01-04          1.0   99.136516  101.801154  98.547165  101.783763
# 2016-01-05          1.0  102.170223  102.266838  98.943286   99.233131
# 2016-01-06          1.0   97.155911   98.904640  96.489269   97.291172
# 2016-01-07          1.0   95.339552   96.740467  93.165717   93.185040
# 2016-01-08          1.0   95.213952   95.754996  93.484546   93.677776
#
#             Adj. Volume
# Date
# 2016-01-04   67649387.0
# 2016-01-05   55790992.0
# 2016-01-06   68457388.0
# 2016-01-07   81094428.0
# 2016-01-08   70798016.0

# %% [markdown]
# ### Bonus Question: Create a program that is capable of downloading multiple assets combine them with the associated time column and save the data into a csv or excel file.

# %%
import pandas as pd
def fetch_quandl_data(symbols,start_date,end_date,price_type):
    df = pd.DataFrame()
    for symbol in symbols:
        
        quandldata = quandl.get("WIKI/{}".format(symbol),start_date=start_date,end_date=end_date)
        quandldata = quandldata[price_type]
        df = pd.concat([df,quandldata],axis=1)
    df.columns = symbols
    df.price_type = price_type
    return df

# %%
start_date = '2016-01-01'
end_date = '2017-05-22'

# %%
df = fetch_quandl_data(['AAPL',"AMZN"],start_date,end_date,"Adj. Close")

# %%
df.head()
# Out:
#                   AAPL    AMZN
# Date
# 2016-01-04  101.783763  636.99
# 2016-01-05   99.233131  633.79
# 2016-01-06   97.291172  632.65
# 2016-01-07   93.185040  607.94
# 2016-01-08   93.677776  607.05

# %%
df.to_csv("bonus.csv")

# %% [markdown]
# ### 2. With the function created in problem 1. download data on both options and equity for the following symbols:
# * AMZN
# * SPY
# * VIX

# %% [markdown]
# ### Equities

# %%
day1 = "2017-06-05"
day2 = "2017-06-06"

# %%
equities_df = pdr.get_data_yahoo(["SPY", "VIX","AMZN"], start=day1, end=day2)
# Out:
# [*********************100%***********************]  3 of 3 downloaded

# %%
equities_df.iloc[4,:,:]
# Out:
#                    AMZN         SPY          VIX
# Date
# 2017-06-05  1011.340027  238.349060  6380.950195
# 2017-06-06  1003.000000  237.587067  6666.669922

# %% [markdown]
# ### Options and its underlying quote

# %%
import datetime
date1 = datetime.datetime(2018,6,17)
date2 = datetime.datetime(2018,6,18)

# %%
date1_unix = int((date1 - datetime.datetime(1970,1,1)).total_seconds())

# %%
t_expired = datetime.datetime(2018,9,21)

# %%
three_months_unix = int((t_expired- datetime.datetime(1970,1,1)).total_seconds())

# %%
import urllib
import json
from pandas.io.json import json_normalize
def get_option_yahoo(symbol):
    unix_time = three_months_unix # GMT: 2018,9,21 Friday 12 AM
    request = urllib.request.Request("https://query2.finance.yahoo.com/v7/finance/options/{}?date={}".format(symbol,unix_time))
    response = urllib.request.urlopen(request)
    option_data = response.read()
    data = json.loads(option_data)
    calls_data = data["optionChain"]["result"][0]["options"][0]["calls"][:]
    puts_data = data["optionChain"]["result"][0]["options"][0]["puts"][:]
    calls_df = pd.DataFrame(calls_data)
    puts_df = pd.DataFrame(puts_data)
    quote_series = pd.Series(data["optionChain"]["result"][0]["quote"])
    return calls_df, puts_df, quote_series

# %% [markdown]
# ### Date 1

# %%
spy_call, spy_put, spy_quote = get_option_yahoo('SPY')
amzn_call, amzn_put, amzn_quote = get_option_yahoo('AMZN')

# %%
spy_call.head()
# Out:
#       ask     bid    change contractSize      contractSymbol currency  \
# 0  222.60  222.24 -3.440002      REGULAR  SPY180921C00055000      USD
# 1  217.63  217.27 -2.909988      REGULAR  SPY180921C00060000      USD
# 2  212.66  212.31  8.949997      REGULAR  SPY180921C00065000      USD
# 3  203.19  202.86  0.000000      REGULAR  SPY180921C00070000      USD
# 4  191.53  191.15  0.000000      REGULAR  SPY180921C00075000      USD
#
#    expiration  impliedVolatility  inTheMoney  lastPrice  lastTradeDate  \
# 0  1537488000           1.417972        True     221.50     1529072345
# 1  1537488000           1.356449        True     216.77     1529081935
# 2  1537488000           1.301761        True     211.47     1529079986
# 3  1537488000           0.000010        True     197.53     1525706817
# 4  1537488000           0.000010        True     189.56     1525492482
#
#    openInterest  percentChange  strike  volume
# 0             0      -1.529298    55.0      21
# 1             0      -1.324649    60.0     158
# 2             0       4.419315    65.0      10
# 3            98       0.000000    70.0      98
# 4            99       0.000000    75.0      99

# %%
spy_put.head()
# Out:
#     ask  bid  change contractSize      contractSymbol currency  expiration  \
# 0  0.05  0.0    0.00      REGULAR  SPY180921P00055000      USD  1537488000
# 1  0.06  0.0    0.00      REGULAR  SPY180921P00060000      USD  1537488000
# 2  0.06  0.0    0.00      REGULAR  SPY180921P00065000      USD  1537488000
# 3  0.02  0.0    0.01      REGULAR  SPY180921P00070000      USD  1537488000
# 4  0.01  0.0    0.00      REGULAR  SPY180921P00075000      USD  1537488000
#
#    impliedVolatility  inTheMoney  lastPrice  lastTradeDate  openInterest  \
# 0           1.054692       False       0.03     1518114685           299
# 1           1.011724       False       0.01     1520618396          1103
# 2           0.960938       False       0.01     1520610442            41
# 3           0.828127       False       0.02     1524246504          4242
# 4           0.750003       False       0.02     1521830255          1403
#
#    percentChange  strike  volume
# 0            0.0    55.0      18
# 1            0.0    60.0      80
# 2            0.0    65.0       6
# 3          100.0    70.0       1
# 4            0.0    75.0    1280

# %%
spy_quote
# Out:
# ask                                                       0
# askSize                                                  10
# averageDailyVolume10Day                            76936685
# averageDailyVolume3Month                           86874682
# bid                                                       0
# bidSize                                                  18
# currency                                                USD
# esgPopulated                                          False
# exchange                                                PCX
# exchangeDataDelayedBy                                     0
# exchangeTimezoneName                       America/New_York
# exchangeTimezoneShortName                               EDT
# fiftyDayAverage                                     272.176
# fiftyDayAverageChange                               4.85382
# fiftyDayAverageChangePercent                      0.0178334
# fiftyTwoWeekHigh                                     286.58
# fiftyTwoWeekHighChange                             -9.54999
# fiftyTwoWeekHighChangePercent                     -0.033324
# fiftyTwoWeekLow                                      239.96
# fiftyTwoWeekLowChange                                 37.07
# fiftyTwoWeekLowChangePercent                       0.154484
# fiftyTwoWeekRange                           239.96 - 286.58
# financialCurrency                                       USD
# fullExchangeName                                   NYSEArca
# gmtOffSetMilliseconds                             -14400000
# language                                              en-US
# longName                              SPDRÂ S&amp;P 500 ETF
# market                                            us_market
# marketCap                                      270514798592
# marketState                                          CLOSED
# messageBoardId                                finmb_6160262
# postMarketChange                                  -0.589996
# postMarketChangePercent                           -0.212895
# postMarketPrice                                      276.54
# postMarketTime                                   1529107196
# priceHint                                                 2
# quoteSourceName                      Nasdaq Real Time Price
# quoteType                                               ETF
# regularMarketChange                               -0.454407
# regularMarketChangePercent                        -0.163759
# regularMarketDayHigh                                 277.51
# regularMarketDayLow                                  275.35
# regularMarketDayRange                       275.35 - 277.51
# regularMarketOpen                                     276.6
# regularMarketPreviousClose                          277.484
# regularMarketPrice                                   277.03
# regularMarketTime                                1529092804
# regularMarketVolume                               120045562
# sharesOutstanding                                 976481984
# shortName                                      SPDR S&P 500
# sourceInterval                                           15
# symbol                                                  SPY
# tradeable                                              True
# trailingThreeMonthNavReturns                           0.16
# trailingThreeMonthReturns                              0.14
# twoHundredDayAverage                                270.447
# twoHundredDayAverageChange                          6.58334
# twoHundredDayAverageChangePercent                 0.0243425
# ytdReturn                                              1.98
# dtype: object

# %%
date1_str = date1.strftime("%Y%m%d")
date2_str = date2.strftime("%Y%m%d")

# %%
spy_call.to_csv("spy_call_{}.csv".format(date1_str))
spy_put.to_csv("spy_put_{}.csv".format(date1_str))
spy_quote.to_csv("spy_quote_{}.csv".format(date1_str))
amzn_call.to_csv("amzn_call_{}.csv".format(date1_str))
amzn_put.to_csv("amzn_put_{}.csv".format(date1_str))
amzn_quote.to_csv("amzn_quote_{}.csv".format(date1_str))

# %% [markdown]
# ### Date 2

# %%
spy_call, spy_put, spy_quote= get_option_yahoo('SPY')
amzn_call, amzn_put = get_option_yahoo('AMZN')
spy_call.to_csv("spy_call_{}.csv".format(date2_str))
spy_put.to_csv("spy_put_{}.csv".format(date2_str))
spy_quote.to_csv("spy_quote_{}.csv".format(date2_str))
amzn_call.to_csv("amzn_call_{}.csv".format(date2_str))
amzn_put.to_csv("amzn_put_{}.csv".format(date2_str))
amzn_quote.to_csv("amzn_quote_{}.csv".format(date2_str))

# %% [markdown]
# ### 3. Write a paragraph describing the symbols you are downloading data for.
#
# * SPY: abbreviation of SPDRÂ S&P 500 ETF. It seeks to provide investment results that, before expenses, correspond generally to the price and yield performance of the S&P 500® Index (the "Index"). A ETF(exchange-traded fund) is a marketable security that tracks an index, a commodity, bonds, or a basket of assets like an index fund. Unlike mutual funds, an ETF trades like a common stock on a stock exchange.
#
# * VIX: The Volatility Index, or VIX, is an index created by the Chicago Board Options Exchange (CBOE), which shows the market's expectation of 30-day volatility. It is constructed using the implied volatilities on S&P 500 index options. This volatility is meant to be forward looking, is calculated from both calls and puts, and is a widely used measure of market risk. The VIX is often referred to as the "investor fear gauge."
#
# * option symbols:
#     - The basic parts of the new option symbols are:
#
#         Root Symbol + Expiration Year(yy) + Expiration Month(mm) + Expiration Day(dd) + Call/Put Indicator (C or P) + Strike Price Dollars + Strike Price Fraction of Dollars (which can include decimals)
#
#     - the Google September 2010 530 strike price call will have the following symbol:
#
#         GOOG100917C00530000
# * When each option expires:
#     - The typical increments for these options were 3 months, 6 months, 9 months, and 1 year. Typical cycles for an option would look something like this:
#
#         - January expiration, April expiration, July expiration, October expiration
#         - February expiration, May expiration, August expiration, November expiration
#         - March expiration, June expiration, September expiration, December expiration
#     - Standard options expiration occurs on the third Friday of each month. As a result, the last day to trade options in the standard monthly cycles is the third Friday of each month, which will be between the 15th and 21st day of the month. If the third Friday of the month falls on a market holiday, then the final day to trade the standard monthly options will be Thursday of that same week.
#     - Any expiration date that isn't on the third Friday of the month is considered to be non-standard, which includes weekly and quarterly expiration cycles. Weekly expiration cycles typically expire every Friday, except during the weeks of quarterly expirations.
#
#
# ___
# |Expiration Type|Last Day to Trade |Standard or Non-Standard|
# |-|-|-|
# |Monthly |Third Friday of Each Month|Standard|
# |Weekly|Every Friday, Except Quarterly Expiration Weeks|Non-Standard|
# |Quarterly|Last Trading Day of March, June, September, and December|Non-Standard|

# %% [markdown]
# ### 4. The following items will also need to be recorded:
# * The underlying equity or ETF price at the exact moment when the rest of the data is downloaded.
# * The short-term interest rate
# * Time to maturaty

# %% [markdown]
# ### Three months risk free rate:
# Here we choose the three months treasury bills yield on 2018 Jun 4: 1.90%

# %%
r_three_months = 0.019

# %% [markdown]
# ### Underlying Price

# %%
spy_quote_d1 = pd.Series.from_csv("spy_quote_{}.csv".format(date1_str))
spy_quote_d1
# Out:
# /home/jerryxyx/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)
# ask                                                     0.0
# askSize                                                  10
# averageDailyVolume10Day                            76936685
# averageDailyVolume3Month                           86874682
# bid                                                     0.0
# bidSize                                                  18
# currency                                                USD
# esgPopulated                                          False
# exchange                                                PCX
# exchangeDataDelayedBy                                     0
# exchangeTimezoneName                       America/New_York
# exchangeTimezoneShortName                               EDT
# fiftyDayAverage                                   272.17618
# fiftyDayAverageChange                              4.853821
# fiftyDayAverageChangePercent                    0.017833378
# fiftyTwoWeekHigh                                     286.58
# fiftyTwoWeekHighChange                            -9.549988
# fiftyTwoWeekHighChangePercent                   -0.03332399
# fiftyTwoWeekLow                                      239.96
# fiftyTwoWeekLowChange                             37.069992
# fiftyTwoWeekLowChangePercent                     0.15448405
# fiftyTwoWeekRange                           239.96 - 286.58
# financialCurrency                                       USD
# fullExchangeName                                   NYSEArca
# gmtOffSetMilliseconds                             -14400000
# language                                              en-US
# longName                              SPDRÂ S&amp;P 500 ETF
# market                                            us_market
# marketCap                                      270514798592
# marketState                                          CLOSED
# messageBoardId                                finmb_6160262
# postMarketChange                                -0.58999634
# postMarketChangePercent                         -0.21289515
# postMarketPrice                                      276.54
# postMarketTime                                   1529107196
# priceHint                                                 2
# quoteSourceName                      Nasdaq Real Time Price
# quoteType                                               ETF
# regularMarketChange                             -0.45440674
# regularMarketChangePercent                      -0.16375938
# regularMarketDayHigh                                 277.51
# regularMarketDayLow                                  275.35
# regularMarketDayRange                       275.35 - 277.51
# regularMarketOpen                                     276.6
# regularMarketPreviousClose                         277.4844
# regularMarketPrice                                   277.03
# regularMarketTime                                1529092804
# regularMarketVolume                               120045562
# sharesOutstanding                                 976481984
# shortName                                      SPDR S&P 500
# sourceInterval                                           15
# symbol                                                  SPY
# tradeable                                              True
# trailingThreeMonthNavReturns                           0.16
# trailingThreeMonthReturns                              0.14
# twoHundredDayAverage                              270.44666
# twoHundredDayAverageChange                        6.5833435
# twoHundredDayAverageChangePercent               0.024342485
# ytdReturn                                              1.98
# dtype: object

# %%
spy_price = float(spy_quote_d1["regularMarketPrice"])
print("The underlyting price of SPY is {}".format(spy_price))
# Out:
# The underlyting price of SPY is 277.03

# %% [markdown]
# ### Time to maturity

# %%
spy_time = int(spy_quote_d1["regularMarketTime"])
spy_time
# Out:
# 1529092804

# %%
timedelta=(datetime.datetime(2018,9,21)-datetime.datetime.fromtimestamp(spy_time))
time_to_maturity = timedelta.total_seconds()/3600/24/365
print("The time to maturity is {}y".format(time_to_maturity))
# Out:
# The time to maturity is 0.2666665398274987y

# %%
#from wallstreet import Stock, Call, Put

# %%
# s = Stock("AAPL")

# %% [markdown]
# ### 5. Black-Scholes Formula

# %% [markdown]
# $$Call=S N(d_1) - e^{-r T} K N(d_2)$$
# $$Call - Put = df(T) (F-K) = S - e^{-r T} K$$
# where
# $$d_1 = \frac{log(\frac{S}{K})+rT + \frac{\sigma T^2}{2}}{\sigma \sqrt{T}}$$
# $$d_2 = \frac{log(\frac{S}{K})+rT -\frac{\sigma T^2}{2}}{\sigma \sqrt{T}}$$

# %%
import scipy as sp
import numpy as np

def BlackSholesPrice(S,K,T,r,sigma):
    d1 = (np.log(S/K) + r*T + sigma*T**2/2)/sigma/np.sqrt(T)
    d2 = d1 - sigma * np.sqrt(T)

    call_price = S*sp.stats.norm.cdf(d1) - np.exp(-r*T)*K*sp.stats.norm.cdf(d2)
    put_price = call_price + np.exp(-r*T)*K - S
       
    return call_price,put_price

# %%
BlackSholesPrice(100,100,1,0.05,0.3)
# Out:
# (13.58040060570056, 8.703343055771967)

# %% [markdown]
# ### 6. Implement the Bisection method to nd the root of arbitrary functions.

# %%
def bisection(func,interval,tol):
    a,b = interval
    c = (a+b)/2.
    
#     func(a) - func(b)
    while(b-a>tol):
        if func(c) == 0:
            return c
        elif func(a)*func(c)<0:
            b=c
        else:
            a=c
        c = (a+b)/2.
    return c

# %%
bisection(np.sin,(-1,1),1e-6)
# Out:
# 0.0

# %%
def impliedvol(S,K,T,r,price,option_type):
    if(option_type=="c"):
        price_equation = lambda sigma: BlackSholesPrice(S,K,T,r,sigma)[0] - price
    elif(option_type=="p"):
        price_equation = lambda sigma: BlackSholesPrice(S,K,T,r,sigma)[1] - price
        
    imp_vol = bisection(price_equation,(1e-6,2),1e-6)
    return imp_vol

# %% [markdown]
# ### test the numerical function for implied vol

# %%
impliedvol(100,100,1,0.05,13.58,'c')
# Out:
# 0.2999891198117733

# %% [markdown]
# ### read date 1 data

# %%
spy_call_d1 = pd.read_csv("spy_call_{}.csv".format(date1_str))
spy_put_d1 = pd.read_csv("spy_put_{}.csv".format(date1_str))
spy_quote_d1 = pd.Series.from_csv("spy_quote_{}.csv".format(date1_str))
amzn_call_d1 = pd.read_csv("amzn_call_{}.csv".format(date1_str))
amzn_put_d1 = pd.read_csv("amzn_put_{}.csv".format(date1_str))
amzn_quote_d1 = pd.Series.from_csv("amzn_quote_{}.csv".format(date1_str))
# Out:
# /home/jerryxyx/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
spy_call_d1.head(20)
# Out:
#     Unnamed: 0     ask     bid     change contractSize      contractSymbol  \
# 0            0  222.60  222.24  -3.440002      REGULAR  SPY180921C00055000
# 1            1  217.63  217.27  -2.909988      REGULAR  SPY180921C00060000
# 2            2  212.66  212.31   8.949997      REGULAR  SPY180921C00065000
# 3            3  203.19  202.86   0.000000      REGULAR  SPY180921C00070000
# 4            4  191.53  191.15   0.000000      REGULAR  SPY180921C00075000
# 5            5  172.94  172.32   0.000000      REGULAR  SPY180921C00095000
# 6            6  180.81  180.44   0.000000      REGULAR  SPY180921C00100000
# 7            7  168.67  168.29   0.000000      REGULAR  SPY180921C00110000
# 8            8  158.73  158.36   0.000000      REGULAR  SPY180921C00120000
# 9            9  129.92  129.41   0.000000      REGULAR  SPY180921C00130000
# 10          10  125.11  124.48   0.000000      REGULAR  SPY180921C00135000
# 11          11  112.79  112.35   0.000000      REGULAR  SPY180921C00145000
# 12          12   90.81   90.26   0.000000      REGULAR  SPY180921C00170000
# 13          13  103.41  103.15   0.000000      REGULAR  SPY180921C00175000
# 14          14   88.88   88.43  17.510002      REGULAR  SPY180921C00180000
# 15          15   93.44   93.18   0.000000      REGULAR  SPY180921C00185000
# 16          16   71.71   71.18   0.000000      REGULAR  SPY180921C00190000
# 17          17   83.51   83.26   2.480003      REGULAR  SPY180921C00195000
# 18          18   66.09   65.57   0.000000      REGULAR  SPY180921C00196000
# 19          19   65.16   64.64   0.000000      REGULAR  SPY180921C00197000
#
#    currency  expiration  impliedVolatility  inTheMoney  lastPrice  \
# 0       USD  1537488000           1.417972        True     221.50
# 1       USD  1537488000           1.356449        True     216.77
# 2       USD  1537488000           1.301761        True     211.47
# 3       USD  1537488000           0.000010        True     197.53
# 4       USD  1537488000           0.000010        True     189.56
# 5       USD  1537488000           0.000010        True     173.38
# 6       USD  1537488000           1.363040        True     178.12
# 7       USD  1537488000           1.028569        True     164.04
# 8       USD  1537488000           0.948731        True     155.59
# 9       USD  1537488000           0.000010        True     132.15
# 10      USD  1537488000           0.000010        True     137.07
# 11      USD  1537488000           0.000010        True     101.62
# 12      USD  1537488000           0.000010        True      95.67
# 13      USD  1537488000           0.541997        True     102.85
# 14      USD  1537488000           0.000010        True      88.98
# 15      USD  1537488000           0.498662        True      92.00
# 16      USD  1537488000           0.000010        True      84.56
# 17      USD  1537488000           0.448980        True      82.26
# 18      USD  1537488000           0.000010        True      78.83
# 19      USD  1537488000           0.000010        True      77.88
#
#     lastTradeDate  openInterest  percentChange  strike  volume
# 0      1529072345             0      -1.529298    55.0      21
# 1      1529081935             0      -1.324649    60.0     158
# 2      1529079986             0       4.419315    65.0      10
# 3      1525706817            98       0.000000    70.0      98
# 4      1525492482            99       0.000000    75.0      99
# 5      1513701690             0       0.000000    95.0       2
# 6      1516204506             0       0.000000   100.0       2
# 7      1515598142             0       0.000000   110.0       2
# 8      1515524347            10       0.000000   120.0       2
# 9      1518209158             0       0.000000   130.0      20
# 10     1518718788             0       0.000000   135.0       4
# 11     1500649413             0       0.000000   145.0       2
# 12     1517931592             5       0.000000   170.0       3
# 13     1528381046           482       0.000000   175.0       1
# 14     1513712236           140      24.499794   180.0       2
# 15     1528310447           641       0.000000   185.0      10
# 16     1521468502           331       0.000000   190.0      48
# 17     1528467530           490       3.108553   195.0       2
# 18     1521468482            20       0.000000   196.0      20
# 19     1521468502            36       0.000000   197.0      26

# %%
[1]*4
# Out:
# [1, 1, 1, 1]

# %%
def calculate_IV_for_quotes(option_df,quote_series,r,option_type):
    S = float(quote_series["regularMarketPrice"])
    t0 = spy_time = int(spy_quote_d1["regularMarketTime"])
    t1 = int(option_df["expiration"][0])
    T = (t1-t0)/3600/24/365
    
    def calc_iv(row):
        price = (float(row["bid"])+float(row["ask"]))/2
        K = float(row["strike"])
        return impliedvol(S,K,T,r,price,option_type)
    def calc_price(row):
        price = (float(row["bid"])+float(row["ask"]))/2
        return price
        
    option_df["my_iv"] = option_df.apply(calc_iv,axis=1)
    option_df["time_to_maturity"] = np.array([T]*len(option_df))
    option_df["average_price"] = option_df.apply(calc_price,axis=1)
    return option_df

# %%
spy_call_df = calculate_IV_for_quotes(spy_call_d1,spy_quote_d1,r_three_months,'c')
amzn_call_df = calculate_IV_for_quotes(amzn_call_d1,amzn_quote_d1,r_three_months,'c')
spy_put_df = calculate_IV_for_quotes(spy_put_d1,spy_quote_d1,r_three_months,'p')
amzn_put_df = calculate_IV_for_quotes(amzn_put_d1,amzn_quote_d1,r_three_months,'p')

# %%
spy_put_df.head()
# Out:
#    Unnamed: 0   ask  bid  change contractSize      contractSymbol currency  \
# 0           0  0.05  0.0    0.00      REGULAR  SPY180921P00055000      USD
# 1           1  0.06  0.0    0.00      REGULAR  SPY180921P00060000      USD
# 2           2  0.06  0.0    0.00      REGULAR  SPY180921P00065000      USD
# 3           3  0.02  0.0    0.01      REGULAR  SPY180921P00070000      USD
# 4           4  0.01  0.0    0.00      REGULAR  SPY180921P00075000      USD
#
#    expiration  impliedVolatility  inTheMoney  lastPrice  lastTradeDate  \
# 0  1537488000           1.054692       False       0.03     1518114685
# 1  1537488000           1.011724       False       0.01     1520618396
# 2  1537488000           0.960938       False       0.01     1520610442
# 3  1537488000           0.828127       False       0.02     1524246504
# 4  1537488000           0.750003       False       0.02     1521830255
#
#    openInterest  percentChange  strike  volume     my_iv  time_to_maturity  \
# 0           299            0.0    55.0      18  1.093308           0.26621
# 1          1103            0.0    60.0      80  1.044959           0.26621
# 2            41            0.0    65.0       6  0.984779           0.26621
# 3          4242          100.0    70.0       1  0.844829           0.26621
# 4          1403            0.0    75.0    1280  0.759397           0.26621
#
#    average_price
# 0          0.025
# 1          0.030
# 2          0.030
# 3          0.010
# 4          0.005

# %%
spy_put_df["my_iv"].head()
# Out:
# 0    1.093308
# 1    1.044959
# 2    0.984779
# 3    0.844829
# 4    0.759397
# Name: my_iv, dtype: float64

# %% [markdown]
# ### 7. Present a table reporting the implied volatility values obtained for every maturity, option type and stock. Also compile the average volatilities as described in the previous point. Comment on the observed difference in values obtained for AMZN and SPY. Compare with the current value of the VIX. Comment on what happens when the maturity increases. Comment on what happen when the options become in the money respectively out of the money.
